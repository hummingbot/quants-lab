# %%
import os
import sys
import warnings

warnings.filterwarnings("ignore")
root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

from core.machine_learning.utils import generate_pickle_report

df = generate_pickle_report(root_path=root_path)
df
# Out:
#                                            model_name     connector_name  \
# 0   pipeline_binance_perpetual_ACT-USDT_2024-11-29...  binance_perpetual
# 1   pipeline_binance_perpetual_DOGE-USDT_2024-11-2...  binance_perpetual
# 2   pipeline_binance_perpetual_DOGE-USDT_2024-11-2...  binance_perpetual
# 3   pipeline_binance_perpetual_1000X-USDT_2024-11-...  binance_perpetual
# 4   pipeline_binance_perpetual_TROY-USDT_2024-11-2...  binance_perpetual
# 5   pipeline_binance_perpetual_SOL-USDT_2024-11-29...  binance_perpetual
# 6   pipeline_binance_perpetual_SOL-USDT_2024-11-29...  binance_perpetual
# 7   pipeline_binance_perpetual_AGLD-USDT_2024-11-2...  binance_perpetual
# 8   pipeline_binance_perpetual_1000PEPE-USDT_2024-...  binance_perpetual
# 9   pipeline_binance_perpetual_WLD-USDT_2024-11-28...  binance_perpetual
# 10  pipeline_binance_perpetual_AGLD-USDT_2024-11-2...  binance_perpetual
# 11  pipeline_binance_perpetual_SUI-USDT_2024-11-28...  binance_perpetual
# ...
