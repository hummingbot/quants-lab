# %% [markdown]
# # ETL Pipeline: Download Historical Candle Data
#
# ## 📊 Overview
# This notebook implements an ETL (Extract, Transform, Load) pipeline for downloading historical OHLCV (Open, High, Low, Close, Volume) candle data from cryptocurrency exchanges. It handles rate limiting, batch processing, and data caching for efficient data collection.
#
# ## 🎯 Objectives
# 1. **Data Extraction**: Download historical price data from exchange APIs
# 2. **Batch Processing**: Handle multiple trading pairs and timeframes efficiently
# 3. **Rate Limit Management**: Respect exchange API limits to avoid throttling
# 4. **Data Caching**: Store downloaded data locally for future use
# 5. **Visualization**: Preview downloaded data with interactive charts
#
# ## 📋 Prerequisites
# - Exchange API access (e.g., Binance Perpetual) if you are in the US use OKX
# - Network connection for API calls
# - Sufficient disk space for data storage (~100MB per pair/interval)
#
# ## ⚠️ Important Notes on Rate Limiting
# Currently, Hummingbot candles don't use a shared rate limit (this is planned for future updates). Therefore:
# - **Batch Size**: Keep `BATCH_CANDLES_REQUEST` low (2-3) to avoid hitting limits
# - **Sleep Time**: Increase `SLEEP_REQUEST` (10+ seconds) for safety
# - **Monitor**: Watch for 429 (Too Many Requests) errors and adjust accordingly
#
# ## 📈 Expected Outputs
# - Cached candle data in `app/data/cache/candles/`
# - Multiple timeframe data (1m, 15m, etc.)
# - Interactive candlestick charts for data validation

# %%
from core.data_sources.clob import CLOBDataSource
import warnings

warnings.filterwarnings("ignore")


# Main class to access central limit order book connectors
clob = CLOBDataSource()

# Candles config
CONNECTOR_NAME = "binance_perpetual"
INTERVALS = ["1m"]

DAYS = 7  # Number of days of historical data to download

# Rate limits config
BATCH_CANDLES_REQUEST = 10  # Number of trading pairs to request in each batch
SLEEP_REQUEST = 10  # Seconds to wait between batches
# Out:
# Available Market Feeds:
# ==================================================
#
# binance:
#   - trades_feed

# %%
trading_rules = await clob.get_trading_rules(CONNECTOR_NAME)
trading_pairs = trading_rules.get_all_trading_pairs()
all_candles = {
    interval: await clob.get_candles_batch_last_days(CONNECTOR_NAME, trading_pairs, interval, DAYS, BATCH_CANDLES_REQUEST,
                                                  SLEEP_REQUEST) for interval in INTERVALS
}
clob.dump_candles_cache()
# Out:
# Batch 1/54
# Start: 0, End: 10
# Batch 2/54
# Start: 10, End: 20
# Batch 3/54
# Start: 20, End: 30
# Batch 4/54
# Start: 30, End: 40
# 2025-09-18 23:25:29,381 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,384 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual TAIKO-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 4
#       1 trading_rules = await clob.get_trading_rules(CONNECTOR_NAME)
#       2 trading_pairs = trading_rules.get_all_trading_pairs()
#       3 all_candles = {
# ----> 4     interval: await clob.get_candles_batch_last_days(CONNECTOR_NAME, trading_pairs, interval, DAYS, BATCH_CANDLES_REQUEST,
#       5                                                   SLEEP_REQUEST) for interval in INTERVALS
#       6 }
#       7 clob.dump_candles_cache()
#
# File ~/Documents/code/quants-lab/core/data_sources/clob.py:221, in CLOBDataSource.get_candles_batch_last_days(self, connector_name, trading_pairs, interval, days, batch_size, sleep_time)
#     212 trading_pairs_batch = trading_pairs[start:end]
#     214 tasks = [self.get_candles_last_days(
#     215     connector_name=connector_name,
#     216     trading_pair=trading_pair,
#     217     interval=interval,
#     218     days=days,
#     219 ) for trading_pair in trading_pairs_batch]
# --> 221 candles = await asyncio.gather(*tasks)
#     222 all_candles.extend(candles)
#     223 if i != number_of_calls - 1:
#
# File ~/Documents/code/quants-lab/core/data_sources/clob.py:198, in CLOBDataSource.get_candles_last_days(self, connector_name, trading_pair, interval, days, from_trades)
#     196 end_time = int(time.time())
#     197 start_time = end_time - days * 24 * 60 * 60
# --> 198 return await self.get_candles(connector_name, trading_pair, interval, start_time, end_time, from_trades)
#
# File ~/Documents/code/quants-lab/core/data_sources/clob.py:164, in CLOBDataSource.get_candles(self, connector_name, trading_pair, interval, start_time, end_time, from_trades)
#     158 else:
#     159     candle = self.candles_factory.get_candle(CandlesConfig(
#     160         connector=connector_name,
#     161         trading_pair=trading_pair,
#     162         interval=interval
#     163     ))
# --> 164     candles_df = await candle.get_historical_candles(HistoricalCandlesConfig(
#     165         connector_name=connector_name,
#     166         trading_pair=trading_pair,
#     167         start_time=new_start_time,
#     168         end_time=new_end_time,
#     169         interval=interval
#     170     ))
#     171     if candles_df is None:
#     172         return Candles(candles_df=pd.DataFrame(), connector_name=connector_name, trading_pair=trading_pair,
#     173                        interval=interval)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py:193, in CandlesBase.get_historical_candles(self, config)
#     191 except Exception as e:
#     192     self.logger().exception(f"Error fetching historical candles: {str(e)}")
# --> 193     raise e
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py:172, in CandlesBase.get_historical_candles(self, config)
#     170 while current_end_time >= current_start_time:
#     171     missing_records = int((current_end_time - current_start_time) / self.interval_in_seconds)
# --> 172     candles = await self.fetch_candles(start_time=current_start_time,
#     173                                        end_time=current_end_time,
#     174                                        limit=missing_records)
#     175     if len(candles) <= 1 or missing_records == 0:
#     176         fetched_candles_df = pd.DataFrame(candles, columns=self.columns)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py:258, in CandlesBase.fetch_candles(self, start_time, end_time, limit)
#     256 headers = self._get_rest_candles_headers()
#     257 rest_assistant = await self._api_factory.get_rest_assistant()
# --> 258 candles = await rest_assistant.execute_request(url=self.candles_url,
#     259                                                throttler_limit_id=self._rest_throttler_limit_id,
#     260                                                params=params,
#     261                                                data=self._rest_payload(**kwargs),
#     262                                                headers=headers,
#     263                                                method=self._rest_method)
#     264 arr = self._parse_rest_candles(candles, end_time)
#     265 return np.array(arr).astype(float)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py:47, in RESTAssistant.execute_request(self, url, throttler_limit_id, params, data, method, is_auth_required, return_err, timeout, headers)
#      35 async def execute_request(
#      36     self,
#      37     url: str,
#    (...)     45     headers: Optional[Dict[str, Any]] = None,
#      46 ) -> Union[str, Dict[str, Any]]:
# ---> 47     response = await self.execute_request_and_get_response(
#      48         url=url,
#      49         throttler_limit_id=throttler_limit_id,
#      50         params=params,
#      51         data=data,
#      52         method=method,
#      53         is_auth_required=is_auth_required,
#      54         return_err=return_err,
#      55         timeout=timeout,
#      56         headers=headers,
#      57     )
#      58     response_json = await response.json()
#      59     return response_json
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py:100, in RESTAssistant.execute_request_and_get_response(self, url, throttler_limit_id, params, data, method, is_auth_required, return_err, timeout, headers)
#      98         error_response = await response.text()
#      99         error_text = "N/A" if "<html" in error_response else error_response
# --> 100         raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
#     101                       f"Error: {error_text}")
#     102 return response
#
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,590 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,590 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual BANK-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,592 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,593 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual OMNI-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,593 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,594 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual YGG-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,594 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,595 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual XAI-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,595 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,595 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual ARB-USDC 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,595 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,596 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual SAGA-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,596 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,596 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual LISTA-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,596 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,597 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual PUNDIX-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,597 - hummingbot.data_feed.candles_feed.binance_perpetual_candles.binance_perpetual_candles - ERROR - Error fetching historical candles: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 172, in get_historical_candles
#     candles = await self.fetch_candles(start_time=current_start_time,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/data_feed/candles_feed/candles_base.py", line 258, in fetch_candles
#     candles = await rest_assistant.execute_request(url=self.candles_url,
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 47, in execute_request
#     response = await self.execute_request_and_get_response(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.12/site-packages/hummingbot/core/web_assistant/rest_assistant.py", line 100, in execute_request_and_get_response
#     raise IOError(f"Error executing request {method.name} {url}. HTTP status is {response.status}. "
# OSError: Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}
# 2025-09-18 23:25:29,597 - core.data_sources.clob - ERROR - Error fetching candles for binance_perpetual SHELL-USDT 1m: OSError - Error executing request GET https://fapi.binance.com/fapi/v1/klines. HTTP status is 429. Error: {"code":-1003,"msg":"Too many requests; current limit of IP(181.116.41.62) is 2400 requests per minute. Please use the websocket for live updates to avoid polling the API."}

# %%
from core.data_structures.candles import Candles

# Display info about downloaded candles
print(f"Downloaded data for {len(all_candles[INTERVALS[0]])} trading pairs")
print("\nTrading pairs downloaded:")
for i, candles_obj in enumerate(all_candles[INTERVALS[0]]):
    print(f"{i+1}. {candles_obj.trading_pair}: {len(candles_obj.data)} candles")

# Get the first trading pair as example (BTC-USDT)
candles: Candles = all_candles[INTERVALS[0]][0]
print(f"\nExample: Showing {candles.trading_pair} data")

# %%
candles.plot()
