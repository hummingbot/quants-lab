# %%
from dotenv import load_dotenv

from core.data_sources.clob import CLOBDataSource
import warnings

from core.notifiers import NotificationManager
from research_notebooks.notifiers.hummingbot_status_report import telegram_report

warnings.filterwarnings("ignore")


# Main class to access central limit order book connectors
clob = CLOBDataSource()

# %%
clob.load_candles_cache()
candles = []
for key, value in clob.candles_cache.items():
    if key[-1] == "1m" and key[0] == "binance_perpetual":
        candles.append(value)

# %%
import pandas as pd

def generate_tf_signal(dataframe: pd.DataFrame):
    df = dataframe.copy()
    df.ta.ema(length=20, append=True)
    df.ta.ema(length=200, append=True)
    df.ta.ema(length=500, append=True)
    # Generate EMA crossover signals
    df['signal'] = 0

    # Long signal: EMA_20 > EMA_200 and EMA_20 > EMA_500
    long_condition = (df['EMA_20'] > df['EMA_200']) & (df['EMA_20'] > df['EMA_500'])

    # Short signal: EMA_20 < EMA_200 and EMA_20 < EMA_500
    short_condition = (df['EMA_20'] < df['EMA_200']) & (df['EMA_20'] < df['EMA_500'])

    df.loc[long_condition, 'signal'] = 1
    df.loc[short_condition, 'signal'] = -1
    # Calculate signal intensity based on EMA divergence
    # Distance of EMA_20 from the average of EMA_200 and EMA_500
    ema_long_avg = (df['EMA_200'] + df['EMA_500']) / 2
    ema_divergence = df['EMA_20'] - ema_long_avg

    # Normalize intensity using rolling percentiles for adaptive scaling
    window = 3000  # Rolling window for percentile calculation
    df['ema_divergence_pct'] = ema_divergence.rolling(window).rank(pct=True)

    # Calculate intensity: 0 (neutral) to 1 (maximum strength)
    df['signal_intensity'] = 0.0

    # For long signals: intensity based on how much EMA_20 is above the long EMAs
    long_mask = df['signal'] == 1
    df.loc[long_mask, 'signal_intensity'] = df.loc[long_mask, 'ema_divergence_pct']

    # For short signals: intensity based on how much EMA_20 is below the long EMAs
    short_mask = df['signal'] == -1
    df.loc[short_mask, 'signal_intensity'] = 1 - df.loc[short_mask, 'ema_divergence_pct']

    # Calculate price range for potential grid levels
    df['price_range'] = df['high'].rolling(window).max() - df['low'].rolling(window).min()
    df['range_pct'] = df['price_range'] / df['close']
    return df, df['signal'].iloc[-1], df['signal_intensity'].iloc[-1], df['range_pct'].iloc[-1], df["close"].iloc[-1]

# %%
tf_signal_long = []
tf_signal_short = []
for candle in candles:
    try:
        df, signal, intensity, range_pct, last_price = generate_tf_signal(candle.data)
        if signal == 1 and intensity > 0.7 and range_pct > 0.01:
            tf_signal_long.append((candle.trading_pair, signal, intensity, range_pct, last_price))
        elif signal == -1 and intensity > 0.7 and range_pct > 0.01:
            tf_signal_short.append((candle.trading_pair, signal, intensity, range_pct, last_price))
    except Exception as e:
        print(f"Error processing {candle.trading_pair}: {e}")
# Out:
# Error processing TRADOOR-USDT: 'EMA_500'
# Error processing ASTER-USDT: 'EMA_500'

# %%
long_df = pd.DataFrame(tf_signal_long, columns=['trading_pair', 'signal', 'intensity', 'range_pct', 'last_price']).sort_values(by='intensity', ascending=False)
short_df = pd.DataFrame(tf_signal_short, columns=['trading_pair', 'signal', 'intensity', 'range_pct', 'last_price']).sort_values(by='intensity', ascending=False)

# %%
top_3_long = long_df.head(3)
top_3_short = short_df.head(3)

# %%
top_3_long["start_price"] = top_3_long["last_price"] * (1 - 0.5 * top_3_long["range_pct"])
top_3_long["end_price"] = top_3_long["last_price"] * (1 + 1.5 * top_3_long["range_pct"])
top_3_long["limit_price"] = top_3_long["last_price"] * (1 - 0.7 * top_3_long["range_pct"])
top_3_long
# Out:
#    trading_pair  signal  intensity  range_pct  last_price  start_price  \
# 5      TUT-USDT       1          1 0.14146278     0.07684     0.071405
# 10    CATI-USDT       1          1 0.10440252      0.0954      0.09042
# 32     BAS-USDT       1 0.99733333 0.26273911    0.018977     0.016484
#
#     end_price  limit_price
# 5    0.093145     0.069231
# 10    0.11034     0.088428
# 32   0.026456    0.0154868

# %%
top_3_short["start_price"] = top_3_short["last_price"] * (1 + 0.5 * top_3_short["range_pct"])
top_3_short["end_price"] = top_3_short["last_price"] * (1 - 1.5 * top_3_short["range_pct"])
top_3_short["limit_price"] = top_3_short["last_price"] * (1 + 0.7 * top_3_short["range_pct"])
top_3_short
# Out:
#     trading_pair  signal  intensity  range_pct  last_price  start_price  \
# 219   DRIFT-USDT      -1 0.97866667 0.36668588      0.8675      1.02655
# 178    YALA-USDT      -1      0.978 0.20628415      0.1464       0.1615
# 286     BTR-USDT      -1      0.977 0.23499382     0.12145      0.13572
#
#      end_price  limit_price
# 219    0.39035      1.09017
# 178     0.1011      0.16754
# 286    0.07864     0.141428

# %%
from core.notifiers import NotificationManager, NotificationMessage
from dotenv import load_dotenv
import datetime
load_dotenv()

manager = NotificationManager()
notifier = manager.get_notifier("telegram")

# Format long signals
long_msg = ""
if not top_3_long.empty:
    for _, row in top_3_long.iterrows():
        long_msg += f"🟢 {row['trading_pair']}\n"
        long_msg += f"   💪 Intensity: {row['intensity']:.3f}\n"
        long_msg += f"   💰 Price: ${row['last_price']:.6f}\n"
        long_msg += f"   📊 Range: {row['range_pct']*100:.2f}%\n"
        long_msg += f"   🎯 Entry: ${row['limit_price']:.6f}\n"
        long_msg += f"   🚀 Target: ${row['end_price']:.6f}\n\n"
else:
    long_msg = "   No strong long signals found\n\n"

# Format short signals  
short_msg = ""
if not top_3_short.empty:
    for _, row in top_3_short.iterrows():
        short_msg += f"🔴 {row['trading_pair']}\n"
        short_msg += f"   💪 Intensity: {row['intensity']:.3f}\n"
        short_msg += f"   💰 Price: ${row['last_price']:.6f}\n"
        short_msg += f"   📊 Range: {row['range_pct']*100:.2f}%\n"
        short_msg += f"   🎯 Entry: ${row['limit_price']:.6f}\n"
        short_msg += f"   📉 Target: ${row['end_price']:.6f}\n\n"
else:
    short_msg = "   No strong short signals found\n\n"

current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M UTC")

telegram_report = f"""📈 TREND FOLLOWING SIGNALS
⏰ Time: {current_time}
📊 Timeframe: 1m
🎯 Min Intensity: 70%
📏 Min Range: 1%

🟢 LONG OPPORTUNITIES:
{long_msg}🔴 SHORT OPPORTUNITIES:
{short_msg}💡 Strategy: EMA(20) vs EMA(200/500) crossover
⚡ High intensity = stronger trend divergence
📊 Range % = recent volatility for grid sizing"""

notification = NotificationMessage(
    title="🤖 Trend Following Alert",
    message=telegram_report,
    level="info"
)

# %%
await notifier.send_notification(notification)
# Out:
# True

# %%
import yaml
from datetime import datetime

def generate_grid_config(trading_pair, side, start_price, limit_price, end_price):
    """
    Generate grid controller config
    side: 1 for long, 2 for short
    """
    timestamp = datetime.now().strftime("%Y%m%d_%H%M")
    direction = "long" if side == 1 else "short"
    config_id = f"tf_{trading_pair.lower().replace('-', '_')}_{direction}_{timestamp}"
    
    config = {
        'activation_bounds': '0.003',
        'connector_name': 'binance_perpetual',
        'controller_name': 'grid_strike',
        'controller_type': 'generic',
        'end_price': str(end_price),
        'id': config_id,
        'keep_position': True,
        'leverage': 20,
        'limit_price': str(limit_price),
        'max_open_orders': 10,
        'max_orders_per_batch': 2,
        'min_order_amount_quote': '10',
        'min_spread_between_orders': '0.002',
        'order_frequency': 5,
        'position_mode': 'HEDGE',
        'side': side,
        'start_price': str(start_price),
        'total_amount_quote': '400',
        'trading_pair': trading_pair,
        'triple_barrier_config': {
            'open_order_type': 3,
            'take_profit': '0.0035',
            'take_profit_order_type': 3
        }
    }
    
    return config

# Generate configs for top signals
all_configs = []

# Process long signals
for _, row in top_3_long.iterrows():
    config = generate_grid_config(
        trading_pair=row['trading_pair'],
        side=1,  # long
        start_price=row['start_price'],
        limit_price=row['limit_price'], 
        end_price=row['end_price']
    )
    all_configs.append(config)
    print(f"✅ Generated LONG config for {row['trading_pair']}")

# Process short signals  
for _, row in top_3_short.iterrows():
    config = generate_grid_config(
        trading_pair=row['trading_pair'],
        side=2,  # short
        start_price=row['start_price'],
        limit_price=row['limit_price'],
        end_price=row['end_price'] 
    )
    all_configs.append(config)
    print(f"✅ Generated SHORT config for {row['trading_pair']}")

print(f"\n📋 Total configs generated: {len(all_configs)}")
# Out:
# ✅ Generated LONG config for TUT-USDT
# ✅ Generated LONG config for CATI-USDT
# ✅ Generated LONG config for BAS-USDT
# ✅ Generated SHORT config for DRIFT-USDT
# ✅ Generated SHORT config for YALA-USDT
# ✅ Generated SHORT config for BTR-USDT
#
# 📋 Total configs generated: 6

# %%
from hummingbot_api_client import HummingbotAPIClient

client = HummingbotAPIClient(base_url="http://localhost:8000")
await client.init()

# %%
for config in all_configs:
    await client.controllers.create_or_update_controller_config(config_name=config['id'], config=config)

# %%
await client.bot_orchestration.deploy_v2_controllers(
    instance_name="cohort-12-tf",
    credentials_profile="master_account",
    controllers_config=[config["id"] for config in all_configs],
)
# Out:
# {'success': True,
#  'message': 'Instance cohort-12-tf created successfully.',
#  'script_config_generated': 'cohort-12-tf-20250919-143723.yml',
#  'controllers_deployed': ['tf_tut_usdt_long_20250919_1427',
#   'tf_cati_usdt_long_20250919_1427',
#   'tf_bas_usdt_long_20250919_1427',
#   'tf_drift_usdt_short_20250919_1427',
#   'tf_yala_usdt_short_20250919_1427',
#   'tf_btr_usdt_short_20250919_1427']}

# %%
await client.bot_orchestration.get_active_bots_status()
# Out:
# {'status': 'success',
#  'data': {'cohort-12-tf': {'status': 'running',
#    'performance': {'tf_tut_usdt_long_20250919_1427': {'status': 'running',
#      'performance': {'realized_pnl_quote': 0.0,
#       'unrealized_pnl_quote': 4.81640947,
#       'unrealized_pnl_pct': 0.44434712804699367,
#       'realized_pnl_pct': 0.0,
#       'global_pnl_quote': 4.81640947,
#       'global_pnl_pct': 0.44434712804699367,
#       'volume_traded': 1083.92947,
#       'positions_summary': [],
#       'close_type_counts': {}}},
#     'tf_cati_usdt_long_20250919_1427': {'status': 'running',
#      'performance': {'realized_pnl_quote': 0.0,
#       'unrealized_pnl_quote': -11.27885728,
#       'unrealized_pnl_pct': -1.4699635659726407,
#       'realized_pnl_pct': 0.0,
#       'global_pnl_quote': -11.27885728,
#       'global_pnl_pct': -1.4699635659726407,
#       'volume_traded': 767.28822,
#       'positions_summary': [],
#       'close_type_counts': {}}},
#     'tf_bas_usdt_long_20250919_1427': {'status': 'running',
#      'performance': {'realized_pnl_quote': 0.0,
#       'unrealized_pnl_quote': -1.27825381,
#       'unrealized_pnl_pct': -0.1713566469131013,
#       'realized_pnl_pct': 0.0,
#       'global_pnl_quote': -1.27825381,
#       'global_pnl_pct': -0.1713566469131013,
#       'volume_traded': 745.961031,
#       'positions_summary': [],
#       'close_type_counts': {}}},
#     'tf_drift_usdt_short_20250919_1427': {'status': 'running',
#      'performance': {'realized_pnl_quote': 0.0,
#       'unrealized_pnl_quote': 0.0,
#       'unrealized_pnl_pct': 0.0,
#       'realized_pnl_pct': 0.0,
#       'global_pnl_quote': 0.0,
#       'global_pnl_pct': 0.0,
#       'volume_traded': 0.0,
#       'positions_summary': [],
#       'close_type_counts': {}}},
#     'tf_yala_usdt_short_20250919_1427': {'status': 'running',
#      'performance': {'realized_pnl_quote': 0.0,
#       'unrealized_pnl_quote': 0.0,
#       'unrealized_pnl_pct': 0.0,
#       'realized_pnl_pct': 0.0,
#       'global_pnl_quote': 0.0,
#       'global_pnl_pct': 0.0,
#       'volume_traded': 0.0,
#       'positions_summary': [],
#       'close_type_counts': {}}},
#     'tf_btr_usdt_short_20250919_1427': {'status': 'running',
#      'performance': {'realized_pnl_quote': 0.0,
#       'unrealized_pnl_quote': 0.0,
#       'unrealized_pnl_pct': 0.0,
#       'realized_pnl_pct': 0.0,
#       'global_pnl_quote': 0.0,
#       'global_pnl_pct': 0.0,
#       'volume_traded': 0.0,
#       'positions_summary': [],
#       'close_type_counts': {}}}},
#    'error_logs': [],
#    'general_logs': [{'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39SCIUT63f2b05347bbf9293 for 109 to CLOSE a CATI-USDT position at 0.0965300.',
#      'timestamp': 1758303864.0664964,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BCIUT63f2b05907ed59293 for 109 to OPEN a CATI-USDT position at 0.0959800.',
#      'timestamp': 1758303870.130659,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39SCIUT63f2b05347bbf9293. [clock=2025-09-19 17:44:30+00:00]',
#      'timestamp': 1758303870.7835135,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39SCIUT63f2b05347bbf9293.',
#      'timestamp': 1758303871.1229382,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39BCIUT63f2b05907ed59293. [clock=2025-09-19 17:44:38+00:00]',
#      'timestamp': 1758303878.8303177,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39SCIUT63f2b061ad4da9293 for 109 to CLOSE a CATI-USDT position at 0.0965300.',
#      'timestamp': 1758303879.1613388,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BCIUT63f2b05907ed59293.',
#      'timestamp': 1758303879.170188,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39SCIUT63f2b061ad4da9293. [clock=2025-09-19 17:44:39+00:00]',
#      'timestamp': 1758303879.8383691,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BCIUT63f2b062a39ac9293 for 109 to OPEN a CATI-USDT position at 0.0959800.',
#      'timestamp': 1758303880.1707783,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39SCIUT63f2b061ad4da9293.',
#      'timestamp': 1758303880.1804986,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39BCIUT63f2b062a39ac9293. [clock=2025-09-19 17:44:40+00:00]',
#      'timestamp': 1758303880.853268,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39SCIUT63f2b0639b5ba9293 for 109 to CLOSE a CATI-USDT position at 0.0965300.',
#      'timestamp': 1758303881.1902983,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BCIUT63f2b062a39ac9293.',
#      'timestamp': 1758303881.2002327,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b04f6a5ff9293. [clock=2025-09-19 17:44:44+00:00]',
#      'timestamp': 1758303884.8832934,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b04f6a5ff9293.',
#      'timestamp': 1758303885.2226646,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BCIUT63f2b068682e19293 for 109 to OPEN a CATI-USDT position at 0.0959800.',
#      'timestamp': 1758303886.2003865,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39BCIUT63f2b068682e19293. [clock=2025-09-19 17:44:46+00:00]',
#      'timestamp': 1758303886.888273,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b0695caaf9293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303887.1979897,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BCIUT63f2b068682e19293.',
#      'timestamp': 1758303887.2093804,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b0695caaf9293. [clock=2025-09-19 17:44:47+00:00]',
#      'timestamp': 1758303887.9079363,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b06a55b109293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303888.2164757,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b0695caaf9293.',
#      'timestamp': 1758303888.227017,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b06a55b109293. [clock=2025-09-19 17:44:48+00:00]',
#      'timestamp': 1758303888.910059,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b06b4a58d9293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303889.2148755,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b06a55b109293.',
#      'timestamp': 1758303889.243692,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b06b4a58d9293. [clock=2025-09-19 17:44:52+00:00]',
#      'timestamp': 1758303892.9618149,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b06f2792f9293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303893.267639,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b06b4a58d9293.',
#      'timestamp': 1758303893.293157,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b06f2792f9293. [clock=2025-09-19 17:44:53+00:00]',
#      'timestamp': 1758303893.96253,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b0701bda49293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303894.2695117,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b06f2792f9293.',
#      'timestamp': 1758303894.280064,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b0701bda49293. [clock=2025-09-19 17:44:54+00:00]',
#      'timestamp': 1758303894.9638133,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b0701bda49293.',
#      'timestamp': 1758303895.2816308,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b071105519293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303895.2818255,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b071105519293. [clock=2025-09-19 17:44:55+00:00]',
#      'timestamp': 1758303895.9647968,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b07204b679293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303896.2824333,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b071105519293.',
#      'timestamp': 1758303896.3090253,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b07204b679293. [clock=2025-09-19 17:44:57+00:00]',
#      'timestamp': 1758303897.968277,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b07204b679293.',
#      'timestamp': 1758303898.278303,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b074e2abb9293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303899.2763834,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'The SELL order x-nbQe1H39SCIUT63f2b0639b5ba9293 amounting to 109/109 CATI has been filled at 0.09653 USDT.',
#      'timestamp': 1758303900.038353,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'SELL order x-nbQe1H39SCIUT63f2b0639b5ba9293 completely filled.',
#      'timestamp': 1758303900.0474522,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39SCIUT63f2b075ddc769293 for 109 to CLOSE a CATI-USDT position at 0.0967500.',
#      'timestamp': 1758303900.303688,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39SCIUT63f2b075ddc769293. [clock=2025-09-19 17:45:02+00:00]',
#      'timestamp': 1758303902.0048356,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39SCIUT63f2b075ddc769293.',
#      'timestamp': 1758303902.3197274,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BCIUT63f2b077c751e9293 for 109 to OPEN a CATI-USDT position at 0.0962000.',
#      'timestamp': 1758303902.3209374,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b074e2abb9293. [clock=2025-09-19 17:45:03+00:00]',
#      'timestamp': 1758303903.0047615,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b078bb7479293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303903.3316891,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b074e2abb9293.',
#      'timestamp': 1758303903.3409815,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39SCIUT63f2b078bc4b79293 for 109 to CLOSE a CATI-USDT position at 0.0967500.',
#      'timestamp': 1758303903.3579772,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39SCIUT63f2b078bc4b79293. [clock=2025-09-19 17:45:04+00:00]',
#      'timestamp': 1758303904.0213704,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39SCIUT63f2b078bc4b79293.',
#      'timestamp': 1758303904.333609,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b078bb7479293. [clock=2025-09-19 17:45:08+00:00]',
#      'timestamp': 1758303908.0285177,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b078bb7479293.',
#      'timestamp': 1758303908.37343,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b07e7d1999293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303909.3527815,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b07e7d1999293. [clock=2025-09-19 17:45:11+00:00]',
#      'timestamp': 1758303911.0545404,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b07e7d1999293.',
#      'timestamp': 1758303911.3918037,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BCIUT63f2b0806d7029293 for 109 to OPEN a CATI-USDT position at 0.0959800.',
#      'timestamp': 1758303911.4356256,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'The BUY order x-nbQe1H39BCIUT63f2b077c751e9293 amounting to 109/109 CATI has been filled at 0.0962 USDT.',
#      'timestamp': 1758303912.8551068,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'BUY order x-nbQe1H39BCIUT63f2b077c751e9293 completely filled.',
#      'timestamp': 1758303912.8656008,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b082543289293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303913.3976123,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b082543289293. [clock=2025-09-19 17:45:14+00:00]',
#      'timestamp': 1758303914.068965,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b082543289293.',
#      'timestamp': 1758303914.4076464,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b08348ad69293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303914.4080722,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b08348ad69293. [clock=2025-09-19 17:45:15+00:00]',
#      'timestamp': 1758303915.070217,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39BCIUT63f2b0806d7029293. [clock=2025-09-19 17:45:15+00:00]',
#      'timestamp': 1758303915.103201,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b0843d2269293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303915.4070842,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b08348ad69293.',
#      'timestamp': 1758303915.4151719,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BCIUT63f2b0806d7029293.',
#      'timestamp': 1758303915.4189243,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39SCIUT63f2b084452ec9293 for 109 to CLOSE a CATI-USDT position at 0.0965300.',
#      'timestamp': 1758303915.4351475,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b0843d2269293. [clock=2025-09-19 17:45:18+00:00]',
#      'timestamp': 1758303918.0986729,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b0843d2269293.',
#      'timestamp': 1758303918.4378283,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39SCIUT63f2b084452ec9293. [clock=2025-09-19 17:45:20+00:00]',
#      'timestamp': 1758303920.1196482,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b08909b3e9293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303920.4137864,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39SCIUT63f2b084452ec9293.',
#      'timestamp': 1758303920.4388595,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BCIUT63f2b0890de7d9293 for 109 to OPEN a CATI-USDT position at 0.0959800.',
#      'timestamp': 1758303920.4390736,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b08909b3e9293. [clock=2025-09-19 17:45:21+00:00]',
#      'timestamp': 1758303921.116573,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b08909b3e9293.',
#      'timestamp': 1758303921.4583871,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b08a014a89293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303921.459148,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b08a014a89293. [clock=2025-09-19 17:45:23+00:00]',
#      'timestamp': 1758303923.1271665,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b08bec27c9293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303923.4629269,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b08a014a89293.',
#      'timestamp': 1758303923.4721851,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b08bec27c9293. [clock=2025-09-19 17:45:24+00:00]',
#      'timestamp': 1758303924.134754,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': '(CATI-USDT) Canceling the limit order x-nbQe1H39BCIUT63f2b0890de7d9293. [clock=2025-09-19 17:45:24+00:00]',
#      'timestamp': 1758303924.1560347,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b08bec27c9293.',
#      'timestamp': 1758303924.473714,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b08ce224b9293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303924.4746811,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39SCIUT63f2b08ce75a19293 for 109 to CLOSE a CATI-USDT position at 0.0965300.',
#      'timestamp': 1758303924.4940555,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BCIUT63f2b0890de7d9293.',
#      'timestamp': 1758303924.5036995,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b08ce224b9293. [clock=2025-09-19 17:45:25+00:00]',
#      'timestamp': 1758303925.1362967,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b08ce224b9293.',
#      'timestamp': 1758303925.4697495,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b08ecae669293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303926.467909,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b08ecae669293. [clock=2025-09-19 17:45:28+00:00]',
#      'timestamp': 1758303928.1699255,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b08ecae669293.',
#      'timestamp': 1758303928.4802978,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b090bb4c59293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303928.510051,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39STTUT63f2b090bb4c59293. [clock=2025-09-19 17:45:29+00:00]',
#      'timestamp': 1758303929.1843433,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER BUY order x-nbQe1H39BTTUT63f2b091b2f5a9293 for 124 to OPEN a TUT-USDT position at 0.0847200.',
#      'timestamp': 1758303929.503658,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39STTUT63f2b090bb4c59293.',
#      'timestamp': 1758303929.5279944,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': '(TUT-USDT) Canceling the limit order x-nbQe1H39BTTUT63f2b091b2f5a9293. [clock=2025-09-19 17:45:30+00:00]',
#      'timestamp': 1758303930.1947792,
#      'level_no': 20,
#      'logger_name': 'hummingbot.strategy.script_strategy_base'},
#     {'level_name': 'INFO',
#      'msg': 'Successfully canceled order x-nbQe1H39BTTUT63f2b091b2f5a9293.',
#      'timestamp': 1758303930.534111,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'},
#     {'level_name': 'INFO',
#      'msg': 'Created LIMIT_MAKER SELL order x-nbQe1H39STTUT63f2b0939e3169293 for 124 to CLOSE a TUT-USDT position at 0.0852600.',
#      'timestamp': 1758303931.5292094,
#      'level_no': 20,
#      'logger_name': 'hummingbot.connector.client_order_tracker'}],
#    'recently_active': True,
#    'source': 'docker'}}}

# %%
await client.bot_orchestration.stop_and_archive_bot(bot_name="cohort-12-tf")
# Out:
# {'status': 'success',
#  'message': 'Stop and archive process started for bot cohort-12-tf',
#  'details': {'input_name': 'cohort-12-tf',
#   'actual_bot_name': 'cohort-12-tf',
#   'container_name': 'cohort-12-tf',
#   'process': 'The bot will be gracefully stopped, archived, and removed in the background. This process typically takes 20-30 seconds.'}}

# %%
await client.archived_bots.list_databases()
# Out:
# ['bots/archived/cohort-12-tf/data/cohort-12-tf-20250919-143723.sqlite',
#  'bots/archived/sapien_grid_bot/data/sapien_grid_bot-20250822-140441.sqlite',
#  'bots/archived/myx_short_grid_bot/data/myx_short_grid_bot-20250804-183238.sqlite',
#  'bots/archived/myx_short_grid_bot_v2/data/myx_short_grid_bot_v2-20250804-184503.sqlite']

# %%
db = "bots/archived/cohort-12-tf/data/cohort-12-tf-20250919-143723.sqlite"

await client.archived_bots.get_database_controllers(db)
# Out:
# {'db_path': 'bots/archived/cohort-12-tf/data/cohort-12-tf-20250919-143723.sqlite',
#  'controllers': [{'id': 'tf_tut_usdt_long_20250919_1427',
#    'controller_id': 1,
#    'timestamp': 1758303447.511206,
#    'type': 'generic',
#    'config': '{"controller_name": "grid_strike", "controller_type": "generic", "total_amount_quote": "1000", "manual_kill_switch": false, "candles_config": [], "initial_positions": [], "leverage": 20, "position_mode": "HEDGE", "connector_name": "binance_perpetual", "trading_pair": "TUT-USDT", "side": 1, "start_price": "0.07140500000000001", "end_price": "0.09314500000000002", "limit_price": "0.069231", "min_spread_between_orders": "0.002", "min_order_amount_quote": "10", "max_open_orders": 10, "max_orders_per_batch": 2, "order_frequency": 5, "activation_bounds": "0.003", "keep_position": true, "triple_barrier_config": {"stop_loss": null, "take_profit": "0.0035", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}}'},
#   {'id': 'tf_cati_usdt_long_20250919_1427',
#    'controller_id': 2,
#    'timestamp': 1758303447.5127416,
#    'type': 'generic',
#    'config': '{"controller_name": "grid_strike", "controller_type": "generic", "total_amount_quote": "1000", "manual_kill_switch": false, "candles_config": [], "initial_positions": [], "leverage": 20, "position_mode": "HEDGE", "connector_name": "binance_perpetual", "trading_pair": "CATI-USDT", "side": 1, "start_price": "0.09041999999999999", "end_price": "0.11034000000000002", "limit_price": "0.08842799999999999", "min_spread_between_orders": "0.002", "min_order_amount_quote": "10", "max_open_orders": 10, "max_orders_per_batch": 2, "order_frequency": 5, "activation_bounds": "0.003", "keep_position": true, "triple_barrier_config": {"stop_loss": null, "take_profit": "0.0035", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}}'},
#   {'id': 'tf_bas_usdt_long_20250919_1427',
#    'controller_id': 3,
#    'timestamp': 1758303447.5138674,
#    'type': 'generic',
#    'config': '{"controller_name": "grid_strike", "controller_type": "generic", "total_amount_quote": "1000", "manual_kill_switch": false, "candles_config": [], "initial_positions": [], "leverage": 20, "position_mode": "HEDGE", "connector_name": "binance_perpetual", "trading_pair": "BAS-USDT", "side": 1, "start_price": "0.016484000000000002", "end_price": "0.026456", "limit_price": "0.015486800000000002", "min_spread_between_orders": "0.002", "min_order_amount_quote": "10", "max_open_orders": 10, "max_orders_per_batch": 2, "order_frequency": 5, "activation_bounds": "0.003", "keep_position": true, "triple_barrier_config": {"stop_loss": null, "take_profit": "0.0035", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}}'},
#   {'id': 'tf_drift_usdt_short_20250919_1427',
#    'controller_id': 4,
#    'timestamp': 1758303447.5151522,
#    'type': 'generic',
#    'config': '{"controller_name": "grid_strike", "controller_type": "generic", "total_amount_quote": "1000", "manual_kill_switch": false, "candles_config": [], "initial_positions": [], "leverage": 20, "position_mode": "HEDGE", "connector_name": "binance_perpetual", "trading_pair": "DRIFT-USDT", "side": 2, "start_price": "1.02655", "end_price": "0.3903499999999999", "limit_price": "1.09017", "min_spread_between_orders": "0.002", "min_order_amount_quote": "10", "max_open_orders": 10, "max_orders_per_batch": 2, "order_frequency": 5, "activation_bounds": "0.003", "keep_position": true, "triple_barrier_config": {"stop_loss": null, "take_profit": "0.0035", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}}'},
#   {'id': 'tf_yala_usdt_short_20250919_1427',
#    'controller_id': 5,
#    'timestamp': 1758303447.5170012,
#    'type': 'generic',
#    'config': '{"controller_name": "grid_strike", "controller_type": "generic", "total_amount_quote": "1000", "manual_kill_switch": false, "candles_config": [], "initial_positions": [], "leverage": 20, "position_mode": "HEDGE", "connector_name": "binance_perpetual", "trading_pair": "YALA-USDT", "side": 2, "start_price": "0.1615", "end_price": "0.1011", "limit_price": "0.16754000000000002", "min_spread_between_orders": "0.002", "min_order_amount_quote": "10", "max_open_orders": 10, "max_orders_per_batch": 2, "order_frequency": 5, "activation_bounds": "0.003", "keep_position": true, "triple_barrier_config": {"stop_loss": null, "take_profit": "0.0035", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}}'},
#   {'id': 'tf_btr_usdt_short_20250919_1427',
#    'controller_id': 6,
#    'timestamp': 1758303447.5181804,
#    'type': 'generic',
#    'config': '{"controller_name": "grid_strike", "controller_type": "generic", "total_amount_quote": "1000", "manual_kill_switch": false, "candles_config": [], "initial_positions": [], "leverage": 20, "position_mode": "HEDGE", "connector_name": "binance_perpetual", "trading_pair": "BTR-USDT", "side": 2, "start_price": "0.13572", "end_price": "0.07864", "limit_price": "0.141428", "min_spread_between_orders": "0.002", "min_order_amount_quote": "10", "max_open_orders": 10, "max_orders_per_batch": 2, "order_frequency": 5, "activation_bounds": "0.003", "keep_position": true, "triple_barrier_config": {"stop_loss": null, "take_profit": "0.0035", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}}'}],
#  'total': 6}

# %%
await client.archived_bots.get_database_trades(db)
# Out:
# {'db_path': 'bots/archived/cohort-12-tf/data/cohort-12-tf-20250919-143723.sqlite',
#  'trades': [{'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303459000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aecfeaa8f9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09865,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0,
#    'trade_fee_in_quote': 0.002111,
#    'exchange_trade_id': '93398168',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.002111},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303459000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aecfea9b79293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09855,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021080000000000005,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '93398187',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.0042190000000000005},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303460000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aecfeb0db9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019017,
#    'amount': 553.0,
#    'leverage': 20,
#    'trade_fee': 0.0,
#    'trade_fee_in_quote': 0.002103,
#    'exchange_trade_id': '51909314',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.002103},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303460000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aecfeb12b9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019017,
#    'amount': 553.0,
#    'leverage': 20,
#    'trade_fee': 0.002103,
#    'trade_fee_in_quote': 0.002103,
#    'exchange_trade_id': '51909315',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.004206},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303465000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aed5a649a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08391,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.0,
#    'trade_fee_in_quote': 0.002097,
#    'exchange_trade_id': '54596454',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.002097},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303466000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aed5a65869293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.0985,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021069999999999995,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398208',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.006326},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303466000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aed5a65669293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.0985,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021069999999999995,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398209',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.008433},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303467000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aed4b1f7c9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09834,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.002104,
#    'trade_fee_in_quote': 0.002104,
#    'exchange_trade_id': '93398239',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.010537},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303469000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aeda6d84a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.0839,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.002097,
#    'trade_fee_in_quote': 0.002097,
#    'exchange_trade_id': '54596694',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.004194},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303469000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aeda6d3649293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.0839,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.002097,
#    'trade_fee_in_quote': 0.002097,
#    'exchange_trade_id': '54596695',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.006291},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303469000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aeda6dbb99293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09839,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.002105000000000001,
#    'trade_fee_in_quote': 0.002105,
#    'exchange_trade_id': '93398255',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.012642},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303469000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aed5a64e29293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08379,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.0020940000000000004,
#    'trade_fee_in_quote': 0.002094,
#    'exchange_trade_id': '54596804',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.008385},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303471000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aedc593869293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.0984,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021049999999999992,
#    'trade_fee_in_quote': 0.002105,
#    'exchange_trade_id': '93398258',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.014747},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303473000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aedf359309293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08459,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002097,
#    'trade_fee_in_quote': 0.002097,
#    'exchange_trade_id': '54597818',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.010482},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303473000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aedf3586a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08459,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002097,
#    'trade_fee_in_quote': 0.002097,
#    'exchange_trade_id': '54597819',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.012579},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303474000,
#    'order_id': 'x-nbQe1H39STTUT63f2aedf35b079293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08479,
#    'amount': 48.0,
#    'leverage': 20,
#    'trade_fee': 0.0008129999999999995,
#    'trade_fee_in_quote': 0.000813,
#    'exchange_trade_id': '54597945',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.013392},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303474000,
#    'order_id': 'x-nbQe1H39STTUT63f2aedf35b079293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08479,
#    'amount': 77.0,
#    'leverage': 20,
#    'trade_fee': 0.0013050000000000006,
#    'trade_fee_in_quote': 0.001305,
#    'exchange_trade_id': '54597947',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.014697},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303474000,
#    'order_id': 'x-nbQe1H39STTUT63f2aedf359ab9293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08471,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.002116999999999999,
#    'trade_fee_in_quote': 0.002117,
#    'exchange_trade_id': '54597964',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.016814},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303476000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aed97c1ba9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019022,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0020999999999999994,
#    'trade_fee_in_quote': 0.0021,
#    'exchange_trade_id': '51909354',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.006305999999999999},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303476000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aed97c3a79293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019022,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.002100000000000001,
#    'trade_fee_in_quote': 0.0021,
#    'exchange_trade_id': '51909355',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.008406},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303476000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aede434c39293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019021,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.002099,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '51909356',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.010505},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303476000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aede4351b9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019021,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.002099,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '51909357',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.012604},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303479000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aee3fc9fe9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08459,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0020970000000000016,
#    'trade_fee_in_quote': 0.002097,
#    'exchange_trade_id': '54599930',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.018911},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303480000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aee12049a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09839,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021049999999999992,
#    'trade_fee_in_quote': 0.002105,
#    'exchange_trade_id': '93398272',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.016852},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303480000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aee1203fd9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09839,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021050000000000027,
#    'trade_fee_in_quote': 0.002105,
#    'exchange_trade_id': '93398273',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.018957},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303480000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aee3fc97e9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08449,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0020949999999999996,
#    'trade_fee_in_quote': 0.002095,
#    'exchange_trade_id': '54600382',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.021006},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303486000,
#    'order_id': 'x-nbQe1H39STTUT63f2aeeaad2009293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08456,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.002113999999999998,
#    'trade_fee_in_quote': 0.002114,
#    'exchange_trade_id': '54601250',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.023119999999999998},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303487000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aeeaad1cd9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08449,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002095000000000003,
#    'trade_fee_in_quote': 0.002095,
#    'exchange_trade_id': '54601802',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.025215},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303487000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aeeaad1729293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08449,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0020949999999999996,
#    'trade_fee_in_quote': 0.002095,
#    'exchange_trade_id': '54601803',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.02731},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303488000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aee9b8b5c9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09848,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021069999999999978,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398309',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.021064},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303488000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aee9b8b039293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09848,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021070000000000012,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398310',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.023171},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303488000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aeec9e9399293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019044,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909437',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.014706},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303488000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aeec9e9949293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019044,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909438',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.016808},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303491000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aeef791f79293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.0846,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002097999999999999,
#    'trade_fee_in_quote': 0.002098,
#    'exchange_trade_id': '54602253',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.029408},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303491000,
#    'order_id': 'x-nbQe1H39STTUT63f2aeeba1d5b9293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08479,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999962,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '54602326',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.031509999999999996},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303492000,
#    'order_id': 'x-nbQe1H39STTUT63f2aef06d9fe9293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08545,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002119000000000003,
#    'trade_fee_in_quote': 0.002119,
#    'exchange_trade_id': '54602990',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.033629},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303492000,
#    'order_id': 'x-nbQe1H39STTUT63f2aef06da489293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08549,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002120000000000004,
#    'trade_fee_in_quote': 0.00212,
#    'exchange_trade_id': '54603014',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.035749},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303493000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aef1624859293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08539,
#    'amount': 123.0,
#    'leverage': 20,
#    'trade_fee': 0.0020999999999999977,
#    'trade_fee_in_quote': 0.0021,
#    'exchange_trade_id': '54603852',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.037849},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303493000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aef16243d9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08519,
#    'amount': 123.0,
#    'leverage': 20,
#    'trade_fee': 0.0020949999999999996,
#    'trade_fee_in_quote': 0.002095,
#    'exchange_trade_id': '54604025',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.039944},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303495000,
#    'order_id': 'x-nbQe1H39STTUT63f2aef34b8169293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08572,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002125000000000002,
#    'trade_fee_in_quote': 0.002125,
#    'exchange_trade_id': '54604803',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.042069},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aef81248a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08532,
#    'amount': 123.0,
#    'leverage': 20,
#    'trade_fee': 0.0020979999999999957,
#    'trade_fee_in_quote': 0.002098,
#    'exchange_trade_id': '54606062',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.044167},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aef8123f39293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08532,
#    'amount': 123.0,
#    'leverage': 20,
#    'trade_fee': 0.0020980000000000026,
#    'trade_fee_in_quote': 0.002098,
#    'exchange_trade_id': '54606063',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.046265},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aef630aa89293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019043,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909467',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.01891},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aef630af59293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019043,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909468',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.021012},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aef16a1549293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019041,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909469',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.023114},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aef16a1159293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019041,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.002102000000000003,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909470',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.025216000000000002},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aee7d67c19293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019021,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0020989999999999967,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '51909489',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.027315},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303500000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aee7d68699293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019021,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0020990000000000036,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '51909490',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.029414000000000003},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303502000,
#    'order_id': 'x-nbQe1H39STTUT63f2aef9fb7169293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08532,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.002114999999999999,
#    'trade_fee_in_quote': 0.002115,
#    'exchange_trade_id': '54606474',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.04838},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303502000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aef8125a99293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09855,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021079999999999988,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '93398360',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.025279},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303502000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aef8125d09293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09855,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021080000000000022,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '93398361',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.027387},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303502000,
#    'order_id': 'x-nbQe1H39STTUT63f2aef8124d89293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08549,
#    'amount': 123.0,
#    'leverage': 20,
#    'trade_fee': 0.0021030000000000007,
#    'trade_fee_in_quote': 0.002103,
#    'exchange_trade_id': '54606687',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.050483},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303505000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aefcd9cc39293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08467,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0020989999999999967,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '54607432',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.052582},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303505000,
#    'order_id': 'x-nbQe1H39BTTUT63f2aefcd9dad9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08449,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0020950000000000066,
#    'trade_fee_in_quote': 0.002095,
#    'exchange_trade_id': '54607683',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.054677},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303506000,
#    'order_id': 'x-nbQe1H39STTUT63f2aefdce6c89293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08502,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021079999999999988,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '54608329',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.056785},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303508000,
#    'order_id': 'x-nbQe1H39STTUT63f2aeffb7b809293',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08492,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021059999999999968,
#    'trade_fee_in_quote': 0.002106,
#    'exchange_trade_id': '54609008',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.058891},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303510000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af01a0f529293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08476,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '54609481',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.060993},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aefcd9e8b9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09849,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021069999999999978,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398375',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.029494},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aefcd9eb39293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09849,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021069999999999978,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398376',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.031601},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af01a109b9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09848,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021070000000000047,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398378',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.033708},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af01a10659293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09848,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021069999999999978,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398379',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.035815},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aef34b8c89293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09847,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021069999999999978,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398380',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.037922},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aef34b8f79293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09847,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021070000000000047,
#    'trade_fee_in_quote': 0.002107,
#    'exchange_trade_id': '93398381',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.040029},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aeee84e6e9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09843,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021059999999999968,
#    'trade_fee_in_quote': 0.002106,
#    'exchange_trade_id': '93398388',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.042135},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303512000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aeee84ebc9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09843,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021060000000000037,
#    'trade_fee_in_quote': 0.002106,
#    'exchange_trade_id': '93398389',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.044241},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303515000,
#    'order_id': 'x-nbQe1H39BBSUT63f2af048a4179293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019042,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909589',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.031516},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303515000,
#    'order_id': 'x-nbQe1H39BBSUT63f2af048a46e9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019042,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021019999999999997,
#    'trade_fee_in_quote': 0.002102,
#    'exchange_trade_id': '51909590',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.033618},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303515000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af0666c4b9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08501,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021080000000000057,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '54610431',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.063101},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303515000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af0666cbd9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08501,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021079999999999988,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '54610432',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.065209},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aee5e5f409293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09838,
#    'amount': 97.0,
#    'leverage': 20,
#    'trade_fee': 0.001908,
#    'trade_fee_in_quote': 0.001908,
#    'exchange_trade_id': '93398401',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.046149},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aee5e5f409293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09838,
#    'amount': 10.0,
#    'leverage': 20,
#    'trade_fee': 0.0001959999999999948,
#    'trade_fee_in_quote': 0.000196,
#    'exchange_trade_id': '93398402',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.046345},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BCIUT63f2aee5e5ed39293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09838,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021050000000000027,
#    'trade_fee_in_quote': 0.002105,
#    'exchange_trade_id': '93398403',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.04845},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aeffc49e09293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019033,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021009999999999987,
#    'trade_fee_in_quote': 0.002101,
#    'exchange_trade_id': '51909613',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.035719},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aeffc4a2d9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019033,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021009999999999987,
#    'trade_fee_in_quote': 0.002101,
#    'exchange_trade_id': '51909614',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.03782},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BBSUT63f2af0950fc09293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019031,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021009999999999987,
#    'trade_fee_in_quote': 0.002101,
#    'exchange_trade_id': '51909616',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.039921},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BBSUT63f2af0950f6e9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.019031,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0021010000000000056,
#    'trade_fee_in_quote': 0.002101,
#    'exchange_trade_id': '51909617',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.042022000000000004},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aefaf9d9a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.01902,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0020989999999999967,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '51909625',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.044121},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'BAS-USDT',
#    'base_asset': 'BAS',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BBSUT63f2aefaf9d499293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.01902,
#    'amount': 552.0,
#    'leverage': 20,
#    'trade_fee': 0.0020990000000000036,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '51909626',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.046220000000000004},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303519000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af09450c39293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08488,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021049999999999958,
#    'trade_fee_in_quote': 0.002105,
#    'exchange_trade_id': '54611023',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.067314},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303521000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af0c234819293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08487,
#    'amount': 16.0,
#    'leverage': 20,
#    'trade_fee': 0.00027100000000000735,
#    'trade_fee_in_quote': 0.000271,
#    'exchange_trade_id': '54611181',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.067585},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303521000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af0c234819293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08487,
#    'amount': 108.0,
#    'leverage': 20,
#    'trade_fee': 0.0018329999999999874,
#    'trade_fee_in_quote': 0.001833,
#    'exchange_trade_id': '54611182',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.069418},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303524000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af0d191d09293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09854,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021079999999999988,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '93398439',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.050558},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303524000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af0d1917a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09854,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021079999999999988,
#    'trade_fee_in_quote': 0.002108,
#    'exchange_trade_id': '93398440',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.052666},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303524000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af0c234209293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08472,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021010000000000056,
#    'trade_fee_in_quote': 0.002101,
#    'exchange_trade_id': '54611446',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.071519},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303524000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af066961a9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09837,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021050000000000027,
#    'trade_fee_in_quote': 0.002105,
#    'exchange_trade_id': '93398491',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.054771},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303524000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af0b2fe219293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09836,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021040000000000017,
#    'trade_fee_in_quote': 0.002104,
#    'exchange_trade_id': '93398496',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.056875},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303524000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af0b2fde09293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09836,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021039999999999948,
#    'trade_fee_in_quote': 0.002104,
#    'exchange_trade_id': '93398497',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.058979},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303526000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af10ea2fd9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08459,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0020970000000000016,
#    'trade_fee_in_quote': 0.002097,
#    'exchange_trade_id': '54611725',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.073616},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303528000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af12d4ff79293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09814,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021000000000000046,
#    'trade_fee_in_quote': 0.0021,
#    'exchange_trade_id': '93398605',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.061079},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303529000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af11e04959293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09813,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0020989999999999967,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '93398620',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.063178},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303530000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af14bda6f9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09816,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0021000000000000046,
#    'trade_fee_in_quote': 0.0021,
#    'exchange_trade_id': '93398629',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.065278},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303530000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af13c80109293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08484,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021039999999999948,
#    'trade_fee_in_quote': 0.002104,
#    'exchange_trade_id': '54612172',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.07572},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303530000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af13c80869293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08484,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021040000000000086,
#    'trade_fee_in_quote': 0.002104,
#    'exchange_trade_id': '54612173',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.077824},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303534000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af1891b4e9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08483,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021029999999999938,
#    'trade_fee_in_quote': 0.002103,
#    'exchange_trade_id': '54612536',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.079927},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303534000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af1891be69293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08483,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0021030000000000076,
#    'trade_fee_in_quote': 0.002103,
#    'exchange_trade_id': '54612537',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.08203},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303537000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af1985f6f9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09799,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0020960000000000006,
#    'trade_fee_in_quote': 0.002096,
#    'exchange_trade_id': '93398704',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.067374},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'CATI-USDT',
#    'base_asset': 'CATI',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303537000,
#    'order_id': 'x-nbQe1H39BCIUT63f2af1985fcb9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.09799,
#    'amount': 107.0,
#    'leverage': 20,
#    'trade_fee': 0.0020960000000000006,
#    'trade_fee_in_quote': 0.002096,
#    'exchange_trade_id': '93398705',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.06947},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303539000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af1d5b0aa9293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08465,
#    'amount': 124.0,
#    'leverage': 20,
#    'trade_fee': 0.0020989999999999898,
#    'trade_fee_in_quote': 0.002099,
#    'exchange_trade_id': '54613091',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.084129},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303542000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af2038a689293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08445,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.0021110000000000018,
#    'trade_fee_in_quote': 0.002111,
#    'exchange_trade_id': '54613771',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.08624},
#   {'config_file_path': 'cohort-12-tf-20250919-143723.yml',
#    'strategy': 'v2_with_controllers',
#    'connector_name': 'binance_perpetual',
#    'trading_pair': 'TUT-USDT',
#    'base_asset': 'TUT',
#    'quote_asset': 'USDT',
#    'timestamp': 1758303543000,
#    'order_id': 'x-nbQe1H39BTTUT63f2af2038ae59293',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 0.08426,
#    'amount': 125.0,
#    'leverage': 20,
#    'trade_fee': 0.0021059999999999968,
#    'trade_fee_in_quote': 0.002106,
#    'exchange_trade_id': '54614089',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.088346}],
#  'pagination': {'total': 257, 'limit': 100, 'offset': 0, 'has_more': True}}
