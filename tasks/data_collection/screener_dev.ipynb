# %%
import pandas as pd
import pandas_ta as ta
import os
from dotenv import load_dotenv
from datetime import timedelta

from core.services.timescale_client import TimescaleClient

load_dotenv()

ts_client = TimescaleClient(os.getenv("TIMESCALE_HOST", "localhost"))
await ts_client.connect()

# %%
available_pairs = await ts_client.get_available_pairs()
available_pairs
# Out:
# [('binance_perpetual', '1000000MOG-USDT'),
#  ('binance_perpetual', '1000BONK-USDT'),
#  ('binance_perpetual', '1000CAT-USDT'),
#  ('binance_perpetual', '1000FLOKI-USDT'),
#  ('binance_perpetual', '1000LUNC-USDT'),
#  ('binance_perpetual', '1000PEPE-USDT'),
#  ('binance_perpetual', '1000RATS-USDT'),
#  ('binance_perpetual', '1000SATS-USDT'),
#  ('binance_perpetual', '1000SHIB-USDT'),
#  ('binance_perpetual', '1000XEC-USDT'),
#  ('binance_perpetual', '1INCH-USDT'),
#  ('binance_perpetual', '1MBABYDOGE-USDT'),
#  ('binance_perpetual', 'AAVE-USDT'),
#  ('binance_perpetual', 'ACE-USDT'),
#  ('binance_perpetual', 'ACH-USDT'),
#  ('binance_perpetual', 'ADA-USDT'),
#  ('binance_perpetual', 'AERGO-USDT'),
#  ('binance_perpetual', 'AEVO-USDT'),
#  ('binance_perpetual', 'AGLD-USDT'),
#  ('binance_perpetual', 'AI-USDT'),
#  ('binance_perpetual', 'ALGO-USDT'),
#  ('binance_perpetual', 'ALICE-USDT'),
#  ('binance_perpetual', 'ALPACA-USDT'),
#  ('binance_perpetual', 'ALPHA-USDT'),
#  ('binance_perpetual', 'ALT-USDT'),
#  ('binance_perpetual', 'AMB-USDT'),
#  ('binance_perpetual', 'ANKR-USDT'),
#  ('binance_perpetual', 'APE-USDT'),
#  ('binance_perpetual', 'API3-USDT'),
#  ('binance_perpetual', 'APT-USDT'),
#  ('binance_perpetual', 'AR-USDT'),
#  ('binance_perpetual', 'ARB-USDT'),
#  ('binance_perpetual', 'ARK-USDT'),
#  ('binance_perpetual', 'ARKM-USDT'),
#  ('binance_perpetual', 'ARPA-USDT'),
#  ('binance_perpetual', 'ASTR-USDT'),
#  ('binance_perpetual', 'ATA-USDT'),
#  ('binance_perpetual', 'ATOM-USDT'),
#  ('binance_perpetual', 'AUCTION-USDT'),
#  ('binance_perpetual', 'AVAX-USDT'),
#  ('binance_perpetual', 'AXL-USDT'),
#  ('binance_perpetual', 'AXS-USDT'),
#  ('binance_perpetual', 'BADGER-USDT'),
#  ('binance_perpetual', 'BAKE-USDT'),
#  ('binance_perpetual', 'BAL-USDT'),
#  ('binance_perpetual', 'BANANA-USDT'),
#  ('binance_perpetual', 'BAND-USDT'),
#  ('binance_perpetual', 'BAT-USDT'),
#  ('binance_perpetual', 'BB-USDT'),
#  ('binance_perpetual', 'BEAMX-USDT'),
#  ('binance_perpetual', 'BEL-USDT'),
#  ('binance_perpetual', 'BICO-USDT'),
#  ('binance_perpetual', 'BIGTIME-USDT'),
#  ('binance_perpetual', 'BLUR-USDT'),
#  ('binance_perpetual', 'BLZ-USDT'),
#  ('binance_perpetual', 'BNB-USDT'),
#  ('binance_perpetual', 'BNT-USDT'),
#  ('binance_perpetual', 'BNX-USDT'),
#  ('binance_perpetual', 'BOME-USDT'),
#  ('binance_perpetual', 'BOND-USDT'),
#  ('binance_perpetual', 'BRETT-USDT'),
#  ('binance_perpetual', 'BSV-USDT'),
#  ('binance_perpetual', 'BSW-USDT'),
#  ('binance_perpetual', 'BTCDOM-USDT'),
#  ('binance_perpetual', 'C98-USDT'),
#  ('binance_perpetual', 'CAKE-USDT'),
#  ('binance_perpetual', 'CATI-USDT'),
#  ('binance_perpetual', 'CELO-USDT'),
#  ('binance_perpetual', 'CELR-USDT'),
#  ('binance_perpetual', 'CETUS-USDT'),
#  ('binance_perpetual', 'CFX-USDT'),
#  ('binance_perpetual', 'CHESS-USDT'),
#  ('binance_perpetual', 'CHR-USDT'),
#  ('binance_perpetual', 'CHZ-USDT'),
#  ('binance_perpetual', 'CKB-USDT'),
#  ('binance_perpetual', 'COMBO-USDT'),
#  ('binance_perpetual', 'COMP-USDT'),
#  ('binance_perpetual', 'COS-USDT'),
#  ('binance_perpetual', 'COTI-USDT'),
#  ('binance_perpetual', 'COW-USDT'),
#  ('binance_perpetual', 'CRV-USDT'),
#  ('binance_perpetual', 'CTSI-USDT'),
#  ('binance_perpetual', 'CYBER-USDT'),
#  ('binance_perpetual', 'DAR-USDT'),
#  ('binance_perpetual', 'DASH-USDT'),
#  ('binance_perpetual', 'DEFI-USDT'),
#  ('binance_perpetual', 'DENT-USDT'),
#  ('binance_perpetual', 'DIA-USDT'),
#  ('binance_perpetual', 'DODOX-USDT'),
#  ('binance_perpetual', 'DOGE-USDT'),
#  ('binance_perpetual', 'DOGS-USDT'),
#  ('binance_perpetual', 'DOT-USDT'),
#  ('binance_perpetual', 'DUSK-USDT'),
#  ('binance_perpetual', 'DYDX-USDT'),
#  ('binance_perpetual', 'DYM-USDT'),
#  ('binance_perpetual', 'EDU-USDT'),
#  ('binance_perpetual', 'EGLD-USDT'),
#  ('binance_perpetual', 'EIGEN-USDT'),
#  ('binance_perpetual', 'ENA-USDT'),
#  ('binance_perpetual', 'ENJ-USDT'),
#  ('binance_perpetual', 'ENS-USDT'),
#  ('binance_perpetual', 'EOS-USDT'),
#  ('binance_perpetual', 'ETHFI-USDT'),
#  ('binance_perpetual', 'ETHW-USDT'),
#  ('binance_perpetual', 'FET-USDT'),
#  ('binance_perpetual', 'FIDA-USDT'),
#  ('binance_perpetual', 'FIL-USDT'),
#  ('binance_perpetual', 'FIO-USDT'),
#  ('binance_perpetual', 'FLM-USDT'),
#  ('binance_perpetual', 'FLOW-USDT'),
#  ('binance_perpetual', 'FLUX-USDT'),
#  ('binance_perpetual', 'FTM-USDT'),
#  ('binance_perpetual', 'FXS-USDT'),
#  ('binance_perpetual', 'G-USDT'),
#  ('binance_perpetual', 'GALA-USDT'),
#  ('binance_perpetual', 'GAS-USDT'),
#  ('binance_perpetual', 'GHST-USDT'),
#  ('binance_perpetual', 'GLM-USDT'),
#  ('binance_perpetual', 'GMT-USDT'),
#  ('binance_perpetual', 'GMX-USDT'),
#  ('binance_perpetual', 'GOAT-USDT'),
#  ('binance_perpetual', 'GRT-USDT'),
#  ('binance_perpetual', 'GTC-USDT'),
#  ('binance_perpetual', 'HBAR-USDT'),
#  ('binance_perpetual', 'HFT-USDT'),
#  ('binance_perpetual', 'HIFI-USDT'),
#  ('binance_perpetual', 'HIGH-USDT'),
#  ('binance_perpetual', 'HMSTR-USDT'),
#  ('binance_perpetual', 'HOOK-USDT'),
#  ('binance_perpetual', 'HOT-USDT'),
#  ('binance_perpetual', 'ICP-USDT'),
#  ('binance_perpetual', 'ICX-USDT'),
#  ('binance_perpetual', 'ID-USDT'),
#  ('binance_perpetual', 'ILV-USDT'),
#  ('binance_perpetual', 'IMX-USDT'),
#  ('binance_perpetual', 'INJ-USDT'),
#  ('binance_perpetual', 'IO-USDT'),
#  ('binance_perpetual', 'IOST-USDT'),
#  ('binance_perpetual', 'IOTA-USDT'),
#  ('binance_perpetual', 'IOTX-USDT'),
#  ('binance_perpetual', 'JASMY-USDT'),
#  ('binance_perpetual', 'JOE-USDT'),
#  ('binance_perpetual', 'JTO-USDT'),
#  ('binance_perpetual', 'JUP-USDT'),
#  ('binance_perpetual', 'KAS-USDT'),
#  ('binance_perpetual', 'KAVA-USDT'),
#  ('binance_perpetual', 'KDA-USDT'),
#  ('binance_perpetual', 'KEY-USDT'),
#  ('binance_perpetual', 'KLAY-USDT'),
#  ('binance_perpetual', 'KNC-USDT'),
#  ('binance_perpetual', 'KSM-USDT'),
#  ('binance_perpetual', 'LDO-USDT'),
#  ('binance_perpetual', 'LEVER-USDT'),
#  ('binance_perpetual', 'LINA-USDT'),
#  ('binance_perpetual', 'LISTA-USDT'),
#  ('binance_perpetual', 'LIT-USDT'),
#  ('binance_perpetual', 'LOKA-USDT'),
#  ('binance_perpetual', 'LOOM-USDT'),
#  ('binance_perpetual', 'LPT-USDT'),
#  ('binance_perpetual', 'LQTY-USDT'),
#  ('binance_perpetual', 'LRC-USDT'),
#  ('binance_perpetual', 'LSK-USDT'),
#  ('binance_perpetual', 'LUNA2-USDT'),
#  ('binance_perpetual', 'MAGIC-USDT'),
#  ('binance_perpetual', 'MANA-USDT'),
#  ('binance_perpetual', 'MANTA-USDT'),
#  ('binance_perpetual', 'MASK-USDT'),
#  ('binance_perpetual', 'MAV-USDT'),
#  ('binance_perpetual', 'MAVIA-USDT'),
#  ('binance_perpetual', 'MBOX-USDT'),
#  ('binance_perpetual', 'MEME-USDT'),
#  ('binance_perpetual', 'METIS-USDT'),
#  ('binance_perpetual', 'MEW-USDT'),
#  ('binance_perpetual', 'MINA-USDT'),
#  ('binance_perpetual', 'MKR-USDT'),
#  ('binance_perpetual', 'MOODENG-USDT'),
#  ('binance_perpetual', 'MOVR-USDT'),
#  ('binance_perpetual', 'MTL-USDT'),
#  ('binance_perpetual', 'MYRO-USDT'),
#  ('binance_perpetual', 'NEAR-USDT'),
#  ('binance_perpetual', 'NEIRO-USDT'),
#  ('binance_perpetual', 'NEIROETH-USDT'),
#  ('binance_perpetual', 'NEO-USDT'),
#  ('binance_perpetual', 'NFP-USDT'),
#  ('binance_perpetual', 'NKN-USDT'),
#  ('binance_perpetual', 'NMR-USDT'),
#  ('binance_perpetual', 'NOT-USDT'),
#  ('binance_perpetual', 'NTRN-USDT'),
#  ('binance_perpetual', 'NULS-USDT'),
#  ('binance_perpetual', 'OGN-USDT'),
#  ('binance_perpetual', 'OM-USDT'),
#  ('binance_perpetual', 'OMG-USDT'),
#  ('binance_perpetual', 'OMNI-USDT'),
#  ('binance_perpetual', 'ONDO-USDT'),
#  ('binance_perpetual', 'ONE-USDT'),
#  ('binance_perpetual', 'ONG-USDT'),
#  ('binance_perpetual', 'ONT-USDT'),
#  ('binance_perpetual', 'OP-USDT'),
#  ('binance_perpetual', 'ORBS-USDT'),
#  ('binance_perpetual', 'ORDI-USDT'),
#  ('binance_perpetual', 'OXT-USDT'),
#  ('binance_perpetual', 'PENDLE-USDT'),
#  ('binance_perpetual', 'PEOPLE-USDT'),
#  ('binance_perpetual', 'PERP-USDT'),
#  ('binance_perpetual', 'PHB-USDT'),
#  ('binance_perpetual', 'PIXEL-USDT'),
#  ('binance_perpetual', 'POL-USDT'),
#  ('binance_perpetual', 'POLYX-USDT'),
#  ('binance_perpetual', 'PONKE-USDT'),
#  ('binance_perpetual', 'POPCAT-USDT'),
#  ('binance_perpetual', 'PORTAL-USDT'),
#  ('binance_perpetual', 'POWR-USDT'),
#  ('binance_perpetual', 'PYTH-USDT'),
#  ('binance_perpetual', 'QNT-USDT'),
#  ('binance_perpetual', 'QTUM-USDT'),
#  ('binance_perpetual', 'QUICK-USDT'),
#  ('binance_perpetual', 'RARE-USDT'),
#  ('binance_perpetual', 'RDNT-USDT'),
#  ('binance_perpetual', 'REEF-USDT'),
#  ('binance_perpetual', 'REI-USDT'),
#  ('binance_perpetual', 'REN-USDT'),
#  ('binance_perpetual', 'RENDER-USDT'),
#  ('binance_perpetual', 'REZ-USDT'),
#  ('binance_perpetual', 'RIF-USDT'),
#  ('binance_perpetual', 'RLC-USDT'),
#  ('binance_perpetual', 'RONIN-USDT'),
#  ('binance_perpetual', 'ROSE-USDT'),
#  ('binance_perpetual', 'RPL-USDT'),
#  ('binance_perpetual', 'RSR-USDT'),
#  ('binance_perpetual', 'RUNE-USDT'),
#  ('binance_perpetual', 'RVN-USDT'),
#  ('binance_perpetual', 'SAFE-USDT'),
#  ('binance_perpetual', 'SAGA-USDT'),
#  ('binance_perpetual', 'SAND-USDT'),
#  ('binance_perpetual', 'SANTOS-USDT'),
#  ('binance_perpetual', 'SCR-USDT'),
#  ('binance_perpetual', 'SEI-USDT'),
#  ('binance_perpetual', 'SFP-USDT'),
#  ('binance_perpetual', 'SKL-USDT'),
#  ('binance_perpetual', 'SNX-USDT'),
#  ('binance_perpetual', 'SOL-USDT'),
#  ('binance_perpetual', 'SPELL-USDT'),
#  ('binance_perpetual', 'SSV-USDT'),
#  ('binance_perpetual', 'STEEM-USDT'),
#  ('binance_perpetual', 'STG-USDT'),
#  ('binance_perpetual', 'STMX-USDT'),
#  ('binance_perpetual', 'STORJ-USDT'),
#  ('binance_perpetual', 'STRK-USDT'),
#  ('binance_perpetual', 'STX-USDT'),
#  ('binance_perpetual', 'SUI-USDT'),
#  ('binance_perpetual', 'SUN-USDT'),
#  ('binance_perpetual', 'SUPER-USDT'),
#  ('binance_perpetual', 'SUSHI-USDT'),
#  ('binance_perpetual', 'SXP-USDT'),
#  ('binance_perpetual', 'SYN-USDT'),
#  ('binance_perpetual', 'SYS-USDT'),
#  ('binance_perpetual', 'T-USDT'),
#  ('binance_perpetual', 'TAO-USDT'),
#  ('binance_perpetual', 'THETA-USDT'),
#  ('binance_perpetual', 'TIA-USDT'),
#  ('binance_perpetual', 'TLM-USDT'),
#  ('binance_perpetual', 'TNSR-USDT'),
#  ('binance_perpetual', 'TOKEN-USDT'),
#  ('binance_perpetual', 'TON-USDT'),
#  ('binance_perpetual', 'TRB-USDT'),
#  ('binance_perpetual', 'TROY-USDT'),
#  ('binance_perpetual', 'TRU-USDT'),
#  ('binance_perpetual', 'TRX-USDT'),
#  ('binance_perpetual', 'TURBO-USDT'),
#  ('binance_perpetual', 'TWT-USDT'),
#  ('binance_perpetual', 'UMA-USDT'),
#  ('binance_perpetual', 'UNFI-USDT'),
#  ('binance_perpetual', 'UNI-USDT'),
#  ('binance_perpetual', 'USDC-USDT'),
#  ('binance_perpetual', 'USTC-USDT'),
#  ('binance_perpetual', 'UXLINK-USDT'),
#  ('binance_perpetual', 'VANRY-USDT'),
#  ('binance_perpetual', 'VET-USDT'),
#  ('binance_perpetual', 'VIDT-USDT'),
#  ('binance_perpetual', 'VOXEL-USDT'),
#  ('binance_perpetual', 'W-USDT'),
#  ('binance_perpetual', 'WAXP-USDT'),
#  ('binance_perpetual', 'WIF-USDT'),
#  ('binance_perpetual', 'WLD-USDT'),
#  ('binance_perpetual', 'WOO-USDT'),
#  ('binance_perpetual', 'XAI-USDT'),
#  ('binance_perpetual', 'XEM-USDT'),
#  ('binance_perpetual', 'XLM-USDT'),
#  ('binance_perpetual', 'XMR-USDT'),
#  ('binance_perpetual', 'XRP-USDT'),
#  ('binance_perpetual', 'XTZ-USDT'),
#  ('binance_perpetual', 'XVG-USDT'),
#  ('binance_perpetual', 'XVS-USDT'),
#  ('binance_perpetual', 'YFI-USDT'),
#  ('binance_perpetual', 'YGG-USDT'),
#  ('binance_perpetual', 'ZEC-USDT'),
#  ('binance_perpetual', 'ZEN-USDT'),
#  ('binance_perpetual', 'ZETA-USDT'),
#  ('binance_perpetual', 'ZIL-USDT'),
#  ('binance_perpetual', 'ZK-USDT'),
#  ('binance_perpetual', 'ZRO-USDT'),
#  ('binance_perpetual', 'ZRX-USDT')]

# %%
intervals = ["1m", "3m", "5m", "15m", "1h"]

status = []
for connector_name, trading_pair in available_pairs:
    for interval in intervals:
        try:
            candles = await ts_client.get_candles(connector_name, trading_pair, interval=interval)
            candles_status = {
                "connector_name": connector_name,
                "trading_pair": trading_pair,
                "start": candles.data.timestamp.min(),
                "end": candles.data.timestamp.max()
            }
            status.append(candles_status)
        except Exception as e:
            print(f"Error while parsing {trading_pair} at {interval}: {e}")
            continue
# Out:
# Error while parsing KLAY-USDT at 1m: relation "binance_perpetual_klay_usdt_1m" does not exist
# Error while parsing KLAY-USDT at 3m: relation "binance_perpetual_klay_usdt_3m" does not exist
# Error while parsing KLAY-USDT at 5m: relation "binance_perpetual_klay_usdt_5m" does not exist
# Error while parsing KLAY-USDT at 15m: relation "binance_perpetual_klay_usdt_15m" does not exist
# Error while parsing KLAY-USDT at 1h: relation "binance_perpetual_klay_usdt_1h" does not exist
# Error while parsing UNFI-USDT at 1m: relation "binance_perpetual_unfi_usdt_1m" does not exist
# Error while parsing UNFI-USDT at 3m: relation "binance_perpetual_unfi_usdt_3m" does not exist
# Error while parsing UNFI-USDT at 5m: relation "binance_perpetual_unfi_usdt_5m" does not exist
# Error while parsing UNFI-USDT at 15m: relation "binance_perpetual_unfi_usdt_15m" does not exist
# Error while parsing UNFI-USDT at 1h: relation "binance_perpetual_unfi_usdt_1h" does not exist

# %%
df = pd.DataFrame(status)
df["start"] = pd.to_datetime(df["start"], unit="s")
df["end"] = pd.to_datetime(df["end"], unit="s")
df.sort_values("start")
# Out:
#          connector_name trading_pair               start                 end
# 294   binance_perpetual    BOME-USDT 2024-10-10 00:00:00 2024-11-09 16:00:00
# 850   binance_perpetual   METIS-USDT 2024-10-10 00:00:00 2024-11-09 16:21:00
# 851   binance_perpetual   METIS-USDT 2024-10-10 00:00:00 2024-11-09 16:21:00
# 1380  binance_perpetual    VIDT-USDT 2024-10-10 00:00:00 2024-11-09 16:21:00
# 852   binance_perpetual   METIS-USDT 2024-10-10 00:00:00 2024-11-09 16:20:00
# ...                 ...          ...                 ...                 ...
# 1498  binance_perpetual     ZRX-USDT 2024-11-08 17:00:00 2024-11-09 16:15:00
# 744   binance_perpetual     KNC-USDT 2024-11-08 17:00:00 2024-11-09 16:00:00
# 743   binance_perpetual     KNC-USDT 2024-11-08 17:00:00 2024-11-09 16:15:00
# 733   binance_perpetual     KDA-USDT 2024-11-08 17:00:00 2024-11-09 16:15:00
# 1499  binance_perpetual     ZRX-USDT 2024-11-08 17:00:00 2024-11-09 16:00:00
#
# [1500 rows x 4 columns]

# %%
def calculate_global_screener_metrics(candles_df: pd.DataFrame, connector_name: str, trading_pair: str):
    df = candles_df.copy()
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")
    df = df.set_index("timestamp")
    global_metrics = {}
    
    # 1. Trading Pair (assuming static)
    global_metrics['connector_name'] = connector_name
    global_metrics['trading_pair'] = trading_pair
    
    # 2. Price Analysis
    # Describe price statistics
    global_metrics['price'] = df['close'].describe().to_dict()
    
    # Helper function for percent change, focusing only on the relevant column
    def percent_change(series, period):
        shifted = series.shift(period)
        if shifted.iloc[-1] == 0 or pd.isna(shifted.iloc[-1]):
            return None
        return (series.iloc[-1] - shifted.iloc[-1]) / shifted.iloc[-1]

    # Price Change Over Periods (% CBO 24h, 1w, 1m)
    price_resampled = df['close'].resample('1d').last()  # Daily resampling for consistent periods
    global_metrics['price_cbo'] = {
        '24h': percent_change(price_resampled, 1),
        '1w': percent_change(price_resampled, 7),
        '1m': percent_change(price_resampled, 28)
    }
    
    # 3. Volume Analysis
    # 24h Volume USD
    last_24h = df.loc[df.index >= (df.index[-1] - timedelta(hours=24)), 'volume'].sum()
    global_metrics['volume_24h'] = last_24h

    # Volume % CBO for Different Periods
    volume_resampled = df['volume'].resample('1d').sum()
    global_metrics['volume_cbo'] = {
        '24h': percent_change(volume_resampled, 1),
        '1w': percent_change(volume_resampled, 7),
        '1m': percent_change(volume_resampled, 30)
    }
    
    return global_metrics

# %%
def calculate_interval_screener_metrics(candles_df: pd.DataFrame, connector_name: str, trading_pair: str, interval: str):
    screener_metrics = {}
    
    df = candles_df.copy()
    df['atr_24h'] = ta.atr(df['high'], df['low'], df['close'], length=24)
    df['atr_1w'] = ta.atr(df['high'], df['low'], df['close'], length=7 * 24)
    df['natr_24h'] = ta.natr(df['high'], df['low'], df['close'], length=24)
    df['natr_1w'] = ta.natr(df['high'], df['low'], df['close'], length=7 * 24)
    screener_metrics['natr'] = df[['natr_24h', 'natr_1w']].describe().to_dict()
    
    # Bollinger Bands Width (50, 100, 200 / 2.0)
    for window in [50, 100, 200]:
        bb = ta.bbands(df['close'], length=window, std=2)
        screener_metrics[f'bb_width_{window}'] = bb[f'BBB_{window}_2.0'].mean() / 200
    return screener_metrics
# Out:
# {'1h': {'natr': {'natr_24h': {'count': 714.0,
#     'mean': 1.6350947149492814,
#     'std': 0.35077719527662155,
#     'min': 0.9909145510227584,
#     '25%': 1.3576595214276117,
#     '50%': 1.6208881162867221,
#     '75%': 1.8590090659452223,
#     'max': 2.9076928502906427},
#    'natr_1w': {'count': 570.0,
#     'mean': 1.618303260062746,
#     'std': 0.09807154183624879,
#     'min': 1.394299140784235,
#     '25%': 1.546543352319969,
#     '50%': 1.6322631599670339,
#     '75%': 1.6879250440888005,
#     'max': 1.836680800499064}},
#   'bb_width_50': 0.05372805124209204,
#   'bb_width_100': 0.0826735803418001,
#   'bb_width_200': 0.10278118257370272}}

# %%
intervals = ["1m", "3m", "5m", "15m", "1h"]

connector_name = "binance_perpetual"
trading_pair = "1000FLOKI-USDT"
candles = await ts_client.get_candles(connector_name, trading_pair, interval="1h")

global_metrics = calculate_global_screener_metrics(candles_df=candles.data,
                                                   connector_name=connector_name, 
                                                   trading_pair=trading_pair)

interval_screener_metrics = {}
for selected_interval in intervals:
    candles = await ts_client.get_candles(connector_name, trading_pair, interval=selected_interval)
    interval_screener_metrics[selected_interval] = calculate_interval_screener_metrics(candles_df=candles.data, 
                                                                                       connector_name=connector_name, 
                                                                                       trading_pair=trading_pair, 
                                                                                       interval=selected_interval)
screener_metrics = global_metrics.update(interval_screener_metrics)

# %%
screener_metrics
